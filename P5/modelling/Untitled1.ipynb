# %%
import torch
torch.manual_seed(111)

N=5

A=torch.rand(N,N)
print(A)
A=A*A
print(A)

A.add(0.001,torch.eye(N))
print(A)
print(torch.inverse(A))
# Out:
# tensor([[0.7156, 0.9140, 0.2819, 0.2581, 0.6311],
#         [0.6001, 0.9312, 0.2153, 0.6033, 0.7328],
#         [0.1857, 0.5101, 0.7545, 0.2884, 0.5775],
#         [0.0358, 0.1026, 0.3419, 0.4400, 0.6341],
#         [0.6224, 0.6334, 0.8580, 0.1572, 0.7853]])
# tensor([[0.5120, 0.8354, 0.0794, 0.0666, 0.3983],
#         [0.3601, 0.8671, 0.0463, 0.3639, 0.5370],
#         [0.0345, 0.2602, 0.5692, 0.0832, 0.3335],
#         [0.0013, 0.0105, 0.1169, 0.1936, 0.4021],
#         [0.3874, 0.4013, 0.7361, 0.0247, 0.6167]])
# tensor([[0.5120, 0.8354, 0.0794, 0.0666, 0.3983],
#         [0.3601, 0.8671, 0.0463, 0.3639, 0.5370],
#         [0.0345, 0.2602, 0.5692, 0.0832, 0.3335],
#         [0.0013, 0.0105, 0.1169, 0.1936, 0.4021],
#         [0.3874, 0.4013, 0.7361, 0.0247, 0.6167]])
# tensor([[-5.7729,  4.7190, -6.9666, -4.7170,  6.4619],
#         [ 3.2259, -1.5891,  3.5396,  0.7531, -3.1047],
#         [-2.8584,  1.8628, -0.1047, -2.7371,  2.0653],
# ...
