# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = {'date': ['2014-05-01 18:47:05.069722', '2014-05-01 18:47:05.119994', '2014-05-02 18:47:05.178768', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.280592', '2014-05-03 18:47:05.332662', '2014-05-03 18:47:05.385109', '2014-05-04 18:47:05.436523', '2014-05-04 18:47:05.486877'], 
        'deaths_regiment_1': [34, 43, 14, 15, 15, 14, 31, 25, 62, 41],
        'deaths_regiment_2': [52, 66, 78, 15, 15, 5, 25, 25, 86, 1],
        'deaths_regiment_3': [13, 73, 82, 58, 52, 87, 26, 5, 56, 75],
        'deaths_regiment_4': [44, 75, 26, 15, 15, 14, 54, 25, 24, 72],
        'deaths_regiment_5': [25, 24, 25, 15, 57, 68, 21, 27, 62, 5],
        'deaths_regiment_6': [84, 84, 26, 15, 15, 14, 26, 25, 62, 24],
        'deaths_regiment_7': [46, 57, 26, 15, 15, 14, 26, 25, 62, 41]}
df = pd.DataFrame(data, columns = ['date', 'battle_deaths', 'deaths_regiment_1', 'deaths_regiment_2',
                                   'deaths_regiment_3', 'deaths_regiment_4', 'deaths_regiment_5',
                                   'deaths_regiment_6', 'deaths_regiment_7'])
print(df)
dates = pd.date_range('20130101', periods=20)
df2 = pd.DataFrame(np.random.randn(20, 4),index=dates,columns=list('ABCD'))
print(df2)
df = df.set_index(df.date)

#sns.tsplot([df.deaths_regiment_1, df.deaths_regiment_2, df.deaths_regiment_3, df.deaths_regiment_4,df.deaths_regiment_5, df.deaths_regiment_6, df.deaths_regiment_7], color="indianred")

sns.tsplot([df2.A, df2.B, df2.C, df2.C,
            df2.D], color="indianred")
# Out:
#                          date battle_deaths  deaths_regiment_1  \
# 0  2014-05-01 18:47:05.069722           NaN                 34
# 1  2014-05-01 18:47:05.119994           NaN                 43
# 2  2014-05-02 18:47:05.178768           NaN                 14
# 3  2014-05-02 18:47:05.230071           NaN                 15
# 4  2014-05-02 18:47:05.230071           NaN                 15
# 5  2014-05-02 18:47:05.280592           NaN                 14
# 6  2014-05-03 18:47:05.332662           NaN                 31
# 7  2014-05-03 18:47:05.385109           NaN                 25
# 8  2014-05-04 18:47:05.436523           NaN                 62
# 9  2014-05-04 18:47:05.486877           NaN                 41
#
#    deaths_regiment_2  deaths_regiment_3  deaths_regiment_4  deaths_regiment_5  \
# 0                 52                 13                 44                 25
# 1                 66                 73                 75                 24
# 2                 78                 82                 26                 25
# 3                 15                 58                 15                 15
# 4                 15                 52                 15                 57
# 5                  5                 87                 14                 68
# 6                 25                 26                 54                 21
# 7                 25                  5                 25                 27
# 8                 86                 56                 24                 62
# 9                  1                 75                 72                  5
#
#    deaths_regiment_6  deaths_regiment_7
# 0                 84                 46
# 1                 84                 57
# 2                 26                 26
# 3                 15                 15
# 4                 15                 15
# 5                 14                 14
# 6                 26                 26
# 7                 25                 25
# 8                 62                 62
# 9                 24                 41
#                    A         B         C         D
# 2013-01-01 -1.182453 -2.036433 -0.495475  0.890386
# 2013-01-02  0.241712 -1.574814 -0.863709  0.332334
# 2013-01-03 -1.335305  0.068958  0.707316 -0.318755
# 2013-01-04 -2.162178 -0.100081 -0.623330 -1.294586
# 2013-01-05 -0.068674  0.265698  1.227838 -0.375528
# 2013-01-06  0.392900 -0.777920 -0.319303  0.339298
# C:\Users\sunta\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas.io.sql as pandasql
import numpy as np
import pandas as pd

f = plt.figure()
np.random.seed(22)
sns.set(color_codes=True)
x = np.linspace(0, 15, 31)
data = np.sin(x) + np.random.rand(10, 31) + np.random.randn(10, 1)
sns.tsplot(data=data, ci=[50, 90], color="m")
f.savefig("foo.eps", bbox_inches='tight')
# Out:
# C:\Users\sunta\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
